# %% [markdown]
# ### Preparing the dataset of movies of 2020 and data is collecting from the wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#      Opening  Opening.1                                              Title  \
# 0    JANUARY          3                                         The Grudge
# 1    JANUARY         10                                         Underwater
# 2    JANUARY         10                                        Like a Boss
# 3    JANUARY         10                                      Three Christs
# 4    JANUARY         10                                  Inherit the Viper
# 5    JANUARY         10                                         The Sonata
# 6    JANUARY         10                 The Murder of Nicole Brown Simpson
# 7    JANUARY         17                                  Bad Boys for Life
# 8    JANUARY         17                                           Dolittle
# 9    JANUARY         17                                  A Fall from Grace
# 10   JANUARY         24                                      The Gentlemen
# 11   JANUARY         24                                        The Turning
# 12   JANUARY         24                              The Last Full Measure
# 13   JANUARY         24                                         John Henry
# 14   JANUARY         31                                 The Rhythm Section
# 15   JANUARY         31                                    Gretel & Hansel
# 16   JANUARY         31                                      The Assistant
# 17  FEBRUARY          7                                      Birds of Prey
# 18  FEBRUARY          7                                          The Lodge
# 19  FEBRUARY          7                  Timmy Failure: Mistakes Were Made
# 20  FEBRUARY          7                                         Horse Girl
# 21  FEBRUARY         12             To All the Boys: P.S. I Still Love You
# 22  FEBRUARY         14                                 Sonic the Hedgehog
# 23  FEBRUARY         14                                     Fantasy Island
# 24  FEBRUARY         14                                     The Photograph
# 25  FEBRUARY         14                                           Downhill
# 26  FEBRUARY         14                                   Spy Intervention
# 27  FEBRUARY         14                          The Kindness of Strangers
# 28  FEBRUARY         21                               The Call of the Wild
# 29  FEBRUARY         21                                               Emma
# 30  FEBRUARY         21                           The Last Thing He Wanted
# 31  FEBRUARY         21                                 Brahms: The Boy II
# 32  FEBRUARY         21                                    The Night Clerk
# 33  FEBRUARY         21                      Impractical Jokers: The Movie
# 34  FEBRUARY         28                                  The Invisible Man
# 35  FEBRUARY         28                              All the Bright Places
# 36  FEBRUARY         28                                              Wendy
# 37  FEBRUARY         28                                        Guns Akimbo
# 38     MARCH          6                                             Onward
# 39     MARCH          6                                       The Way Back
# 40     MARCH          6                               Spenser Confidential
# 41     MARCH          6                                         The Banker
# 42     MARCH          6                            The Burnt Orange Heresy
# 43     MARCH          6                                            Swallow
# 44     MARCH          6                                          First Cow
# 45     MARCH         13                                          Bloodshot
# 46     MARCH         13                                           The Hunt
# 47     MARCH         13                                    I Still Believe
# 48     MARCH         13                                         Lost Girls
# 49     MARCH         13                                           Stargirl
# 50     MARCH         13                                The Roads Not Taken
# 51     MARCH         13                      Never Rarely Sometimes Always
# 22                                               [23]
# 23                                               [24]
# 24                                               [25]
# 25                                               [26]
# 26                                               [27]
# 27                                               [28]
# 28                                                [3]
# 29                                                NaN
# 30                                               [29]
# 31                                               [30]
# 32                                               [31]
# 33                                               [32]
# 34                                               [33]
# 35                                               [34]
# 36                                               [35]
# 37                                               [36]
# 38                                               [37]
# 39                                               [38]
# 40                                               [39]
# 41                                               [40]
# 42                                               [41]
# 43                                               [42]
# 44                                               [43]
# 45                                               [44]
# 46                                               [45]
# 47                                               [46]
# 48                                               [47]
# 49                                               [48]
# 50                                               [49]
# 51                                               [50]
# 52                                               [51]
# 53                                               [52]
# 54  No films had been released on this date as res...
# 55                                               [53]
# 56                                               [54]
# 57                                               [55]

# %%
df2
# Out:
#    Opening  Opening.1                                            Title  \
# 0    APRIL          3                                  Coffee & Kareem
# 1    APRIL         10                                Trolls World Tour
# 2    APRIL         10                              Love Wedding Repeat
# 3    APRIL         10                                   The Main Event
# 4    APRIL         10                           We Summon the Darkness
# 5    APRIL         10                                 The Lost Husband
# 6    APRIL         10                                   Corona Zombies
# 7    APRIL         17                                           Sergio
# 8    APRIL         22                                  The Willoughbys
# 9    APRIL         24                                       Extraction
# 10   APRIL         24                               Braking for Whales
# 11   APRIL         25                                    Bad Education
# 12   APRIL         30                                   Dangerous Lies
# 13     MAY          1                              All Day and a Night
# 14     MAY          1                                     The Wretched
# 15     MAY          1                                   The Half of It
# 16     MAY          5                                         Arkansas
# 17     MAY          8                                      Valley Girl
# 18     MAY         12                                           Capone
# 19     MAY         13                                  The Wrong Missy
# 20     MAY         15                                           Scoob!
# 21     MAY         15                                  Blood and Money
# 22     MAY         19                                         Body Cam
# 23     MAY         22                                    The Lovebirds
# 24     MAY         22                                      Inheritance
# 25     MAY         22                                Survive the Night
# 26     MAY         22                                 The Wanting Mare
# 27     MAY         29                                    The High Note
# 28    JUNE          5                                          Shirley
# 29    JUNE          5                  The Last Days of American Crime
# 30    JUNE          5                                            Becky
# 31    JUNE          9                                 Think Like a Dog
# 32    JUNE         12                                      Da 5 Bloods
# 33    JUNE         12                                     Artemis Fowl
# 34    JUNE         12                        The King of Staten Island
# 35    JUNE         16                           Sniper: Assassin's End
# 36    JUNE         18                             You Should Have Left
# 37    JUNE         19                                     Wasp Network
# 38    JUNE         19                                    Feel the Beat
# 39    JUNE         19                                             7500
# 40    JUNE         24                                        Athlete A
# 41    JUNE         26  Eurovision Song Contest: The Story of Fire Saga
# 42    JUNE         26                                     Irresistible
# 43    JUNE         26                                           My Spy
# 44    JUNE         26                         We Bare Bears: The Movie
#
#                                    Production company  \
# 0                                             Netflix
# 1           Universal Pictures / DreamWorks Animation
# 2                                             Netflix
# 3                               Netflix / WWE Studios
# 4                                         Saban Films
# 5                                 Quiver Distribution
# 6                                  Full Moon Features
# 7                                             Netflix
# 8                              Netflix / Bron Studios
# 9                                      Netflix / AGBO
# 10                                  Gravitas Ventures
# 11                                          HBO Films
# 12                                            Netflix
# 13                                            Netflix
# 14                                       IFC Midnight
#
#                                    Production company  \
# 0                 Apple TV+ / A24 / American Zoetrope
# 1     Paramount Pictures / Jurassic Party Productions
# 2                        Netflix / Universal Pictures
# 3   Neon / Well Go USA Entertainment / Elevation P...
# 4                                         Saban Films
# ..                                                ...
# 94  Netflix / Troublemaker Studios / Double R Prod...
# 95        Universal Pictures / Perfect World Pictures
# 96                                     Amazon Studios
# 97          Focus Features / FilmNation Entertainment
# 98                             Netflix / Bron Studios
#
#                                         Cast and crew   Ref.
# 0   Sofia Coppola (director/screenplay); Rashida J...  [167]
# 1   Brian Duffield (director/screenplay); Katherin...  [168]
# 2   Osmany Rodriguez (director/screenplay); Blaise...  [169]
# 3   Brandon Cronenberg (director/screenplay); Andr...  [170]
# 4   Darren Lynn Bousman (director); Arli Margolis,...  [171]
# ..                                                ...    ...
# 94  Robert Rodriguez (director/screenplay); Priyan...  [241]
# 95  Paul Greengrass (director/screenplay); Luke Da...  [242]
# 96  Regina King (director); Kemp Powers (screenpla...  [243]
# 97  Emerald Fennell (director/screenplay); Carey M...  [244]
# 98  Kornél Mundruczó (director); Kata Wéber (scree...  [245]
#
# [99 rows x 6 columns]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\1166741043.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 270  DECEMBER         25       We Can Be Heroes
# 271  DECEMBER         25      News of the World
# 272  DECEMBER         25  One Night in Miami...
# 273  DECEMBER         25  Promising Young Woman
# 274  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 270  Netflix / Troublemaker Studios / Double R Prod...
# 271        Universal Pictures / Perfect World Pictures
# 272                                     Amazon Studios
# 273          Focus Features / FilmNation Entertainment
# 274                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 270  Robert Rodriguez (director/screenplay); Priyan...
# 271  Paul Greengrass (director/screenplay); Luke Da...
# 272  Regina King (director); Kemp Powers (screenpla...
# 273  Emerald Fennell (director/screenplay); Carey M...
# 274  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [241]
# 271  [242]
# 272  [243]
# 273  [244]
# 274  [245]
#
# [275 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '7db67521531b685b4c85dc67d22406cb'

# %%
# from tmdbv3api import *
# from tmdbv3api import Movie

# import json
# import requests
# tmdb=TMDb()
# tmdb.api_key='7db67521531b685b4c85dc67d22406cb'

# %%
# !pip install tmdbv3api

# %% [markdown]
# ### In above dataset we don't have the genres column so we get the 'genres' column from the IMDB Movies Database

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
        return np.NaN
    else:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\2588226551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                              genres
# 0                    Horror Mystery
# 1     Action Horror Science Fiction
# 2                            Comedy
# 3                             Drama
# 4              Crime Thriller Drama
# ..                              ...
# 270    Action Fantasy Family Comedy
# 271  Drama Western Adventure Action
# 272                           Drama
# 273            Thriller Crime Drama
# 274                           Drama
#
# [275 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\1815024756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df['Cast and crew'][0]
# Out:
# 'Nicolas Pesce (director/screenplay); Andrea Riseborough, Demián Bichir, John Cho, Betty Gilpin, Lin Shaye, Jacki Weaver'

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\3667490226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                movie_title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                              genres     director_name           actor_1_name  \
# 0                    Horror Mystery     Nicolas Pesce     Andrea Riseborough
# 1     Action Horror Science Fiction    William Eubank        Kristen Stewart
# 2                            Comedy     Miguel Arteta        Tiffany Haddish
# 3                             Drama         Jon Avnet           Richard Gere
# 4              Crime Thriller Drama    Anthony Jerjen          Josh Hartnett
# ..                              ...               ...                    ...
# 270    Action Fantasy Family Comedy  Robert Rodriguez  Priyanka Chopra Jonas
# 271  Drama Western Adventure Action   Paul Greengrass              Tom Hanks
# 272                           Drama       Regina King      Kingsley Ben-Adir
# 273            Thriller Crime Drama   Emerald Fennell         Carey Mulligan
# 274                           Drama  Kornél Mundruczó          Vanessa Kirby
#
#           actor_2_name     actor_3_name
# 0        Demián Bichir         John Cho
# 1       Vincent Cassel  Jessica Henwick
# 2           Rose Byrne      Salma Hayek
# 3       Peter Dinklage   Walton Goggins
# 4    Margarita Levieva   Chandler Riggs
# ..                 ...              ...
# 270       Pedro Pascal    YaYa Gosselin
# 271      Helena Zengel              NaN
# 272          Eli Goree      Aldis Hodge
# 273         Bo Burnham      Alison Brie
# 274       Shia LaBeouf     Molly Parker
#
# [275 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271   Paul Greengrass              Tom Hanks      Helena Zengel
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                          genres            movie_title
# 0           John Cho                  Horror Mystery             The Grudge
# 1    Jessica Henwick   Action Horror Science Fiction             Underwater
# 2        Salma Hayek                          Comedy            Like a Boss
# 3     Walton Goggins                           Drama          Three Christs
# 4     Chandler Riggs            Crime Thriller Drama      Inherit the Viper
# ..               ...                             ...                    ...
# 270    YaYa Gosselin    Action Fantasy Family Comedy       We Can Be Heroes
# 271              NaN  Drama Western Adventure Action      News of the World
# 272      Aldis Hodge                           Drama  One Night in Miami...
# 273      Alison Brie            Thriller Crime Drama  Promising Young Woman
# 274     Molly Parker                           Drama      Pieces of a Woman
#
# [275 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# comb             29
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_10364\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269       Pete Docter             Jamie Foxx           Tina Fey
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                 genres  \
# 0           John Cho                         Horror Mystery
# 1    Jessica Henwick          Action Horror Science Fiction
# 2        Salma Hayek                                 Comedy
# 3     Walton Goggins                                  Drama
# 4     Chandler Riggs                   Crime Thriller Drama
# ..               ...                                    ...
# 269    Graham Norton  Animation Family Comedy Fantasy Drama
# 270    YaYa Gosselin           Action Fantasy Family Comedy
# 272      Aldis Hodge                                  Drama
# 273      Alison Brie                   Thriller Crime Drama
# 274     Molly Parker                                  Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 269                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 270       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 272  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 273  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 274      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [246 rows x 7 columns]

# %%
new_df20.to_csv('movies_data_2020',index=True)
