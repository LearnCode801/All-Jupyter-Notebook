# %% [markdown]
# ### Appending the dataset of 2016,2017,2018,2019,2020

# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv('movie-1-2-combine')
d2=pd.read_csv('movies_data_2018')
d3=pd.read_csv('movies_data_2019')
d4=pd.read_csv('movies_data_2020')

# %%
d1
# Out:
#       Unnamed: 0          director_name          actor_1_name  \
# 0              0          james cameron           cch pounder
# 1              1         gore verbinski           johnny depp
# 2              2             sam mendes       christoph waltz
# 3              3      christopher nolan             tom hardy
# 4              4            doug walker           doug walker
# ...          ...                    ...                   ...
# 5370        5496            Jim Strouse      Jessica Williams
# 5371        5497            Farhad Mann         Adelaide Kane
# 5372        5498       Hannaleena Hauru        Inka Haapamäki
# 5373        5499  Jonathan A. Rosenbaum  Lou Diamond Phillips
# 5374        5500           Ravi Udyawar        Sridevi Kapoor
#
#                 actor_2_name          actor_3_name  \
# 0           joel david moore             wes studi
# 1              orlando bloom        jack davenport
# 2               rory kinnear      stephanie sigman
# ...

# %%
d2
# Out:
#      Unnamed: 0       director_name     actor_1_name            actor_2_name  \
# 0             0        Adam Robitel        Lin Shaye           Angus Sampson
# 1             1    Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2             2          Simon West   Dominic Cooper          Austin Stowell
# 3             3    Warwick Thornton      Bryan Brown               Sam Neill
# 4             4  Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..          ...                 ...              ...                     ...
# 269         269          Etan Cohen     Will Ferrell          John C. Reilly
# 270         270          Adam McKay   Christian Bale               Amy Adams
# 271         271          Mimi Leder   Felicity Jones            Armie Hammer
# 272         272        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 273         273         David Slade  Fionn Whitehead            Will Poulter
#
# ...

# %%
d3
# Out:
#      Unnamed: 0           director_name         actor_1_name  \
# 0             0            Adam Robitel       Taylor Russell
# 1             1             Jen McGowan    Hermione Corfield
# 2             2       Wilson Coneybeare    Donald Sutherland
# 3             3    Charles Martin Smith  Bryce Dallas Howard
# 4             4             Neil Burger       Bryan Cranston
# ..          ...                     ...                  ...
# 240         240  Nick Bruno, Troy Quane           Will Smith
# 241         241            Greta Gerwig        Saoirse Ronan
# 242         242              Sam Mendes        George MacKay
# 243         243   Destin Daniel Cretton    Michael B. Jordan
# 244         244         Chinonye Chukwu        Alfre Woodard
#
#              actor_2_name      actor_3_name  \
# 0            Logan Miller  Deborah Ann Woll
# 1             Jay Paulson      Sean O'Bryan
# 2      Vincent Kartheiser     Oliver Dennis
# 3      Edward James Olmos   Alexandra Shipp
# ...

# %%
d4
# Out:
#      Unnamed: 0     director_name           actor_1_name       actor_2_name  \
# 0             0     Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1             1    William Eubank        Kristen Stewart     Vincent Cassel
# 2             2     Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3             3         Jon Avnet           Richard Gere     Peter Dinklage
# 4             4    Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..          ...               ...                    ...                ...
# 241         269       Pete Docter             Jamie Foxx           Tina Fey
# 242         270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 243         272       Regina King      Kingsley Ben-Adir          Eli Goree
# 244         273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 245         274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
# ...

# %%
d1.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'combine'],
#       dtype='object')

# %%
d2.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
d3.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
d4.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
d1=d1.rename(columns={'combine':'comb'})

# %%
d1.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
df = d1.append(d2.append(d3.append(d4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# C:\Users\Muhammad Talha Awan\AppData\Local\Temp\ipykernel_2972\1792203715.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = d1.append(d2.append(d3.append(d4,ignore_index=True),ignore_index=True),ignore_index=True)
#       Unnamed: 0      director_name           actor_1_name      actor_2_name  \
# 0              0      james cameron            cch pounder  joel david moore
# 1              1     gore verbinski            johnny depp     orlando bloom
# 2              2         sam mendes        christoph waltz      rory kinnear
# 3              3  christopher nolan              tom hardy    christian bale
# 4              4        doug walker            doug walker        rob walker
# ...          ...                ...                    ...               ...
# 6135         269        Pete Docter             Jamie Foxx          Tina Fey
# ...

# %%
print(d1.shape)
print(d2.shape)
print(d3.shape)
print(d4.shape)
# Out:
# (5375, 8)
# (274, 8)
# (245, 8)
# (246, 8)

# %%
col=df.columns
col
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         james cameron            cch pounder  joel david moore
# 1        gore verbinski            johnny depp     orlando bloom
# 2            sam mendes        christoph waltz      rory kinnear
# 3     christopher nolan              tom hardy    christian bale
# 4           doug walker            doug walker        rob walker
# ...                 ...                    ...               ...
# 6135        Pete Docter             Jamie Foxx          Tina Fey
# 6136   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6137        Regina King      Kingsley Ben-Adir         Eli Goree
# 6138    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6139   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                 genres  \
# 0                wes studi        action adventure fantasy sci-fi
# ...

# %%
col=df.columns
col
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
for i in col:
    df[i]=df[i].str.lower()

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         james cameron            cch pounder  joel david moore
# 1        gore verbinski            johnny depp     orlando bloom
# 2            sam mendes        christoph waltz      rory kinnear
# 3     christopher nolan              tom hardy    christian bale
# 4           doug walker            doug walker        rob walker
# ...                 ...                    ...               ...
# 6135        pete docter             jamie foxx          tina fey
# 6136   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6137        regina king      kingsley ben-adir         eli goree
# 6138    emerald fennell         carey mulligan        bo burnham
# 6139   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# 0                wes studi        action adventure fantasy sci-fi
# ...

# %%
df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# comb             1
# dtype: int64

# %%
df.dropna(how='any',inplace=True)

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         james cameron            cch pounder  joel david moore
# 1        gore verbinski            johnny depp     orlando bloom
# 2            sam mendes        christoph waltz      rory kinnear
# 3     christopher nolan              tom hardy    christian bale
# 4           doug walker            doug walker        rob walker
# ...                 ...                    ...               ...
# 6135        pete docter             jamie foxx          tina fey
# 6136   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6137        regina king      kingsley ben-adir         eli goree
# 6138    emerald fennell         carey mulligan        bo burnham
# 6139   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# 0                wes studi        action adventure fantasy sci-fi
# ...

# %%
df.reset_index()
# Out:
#       index      director_name           actor_1_name      actor_2_name  \
# 0         0      james cameron            cch pounder  joel david moore
# 1         1     gore verbinski            johnny depp     orlando bloom
# 2         2         sam mendes        christoph waltz      rory kinnear
# 3         3  christopher nolan              tom hardy    christian bale
# 4         4        doug walker            doug walker        rob walker
# ...     ...                ...                    ...               ...
# 6134   6135        pete docter             jamie foxx          tina fey
# 6135   6136   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6136   6137        regina king      kingsley ben-adir         eli goree
# 6137   6138    emerald fennell         carey mulligan        bo burnham
# 6138   6139   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# ...

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         james cameron            cch pounder  joel david moore
# 1        gore verbinski            johnny depp     orlando bloom
# 2            sam mendes        christoph waltz      rory kinnear
# 3     christopher nolan              tom hardy    christian bale
# 4           doug walker            doug walker        rob walker
# ...                 ...                    ...               ...
# 6135        pete docter             jamie foxx          tina fey
# 6136   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6137        regina king      kingsley ben-adir         eli goree
# 6138    emerald fennell         carey mulligan        bo burnham
# 6139   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# 0                wes studi        action adventure fantasy sci-fi
# ...

# %%
df.shape
# Out:
# (6139, 7)

# %%
df.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
df.shape
# Out:
# (6138, 7)

# %%
df=df.reset_index()

# %%
df
# Out:
#       index      director_name           actor_1_name      actor_2_name  \
# 0         0      james cameron            cch pounder  joel david moore
# 1         1     gore verbinski            johnny depp     orlando bloom
# 2         2         sam mendes        christoph waltz      rory kinnear
# 3         3  christopher nolan              tom hardy    christian bale
# 4         4        doug walker            doug walker        rob walker
# ...     ...                ...                    ...               ...
# 6133   6135        pete docter             jamie foxx          tina fey
# 6134   6136   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6135   6137        regina king      kingsley ben-adir         eli goree
# 6136   6138    emerald fennell         carey mulligan        bo burnham
# 6137   6139   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
df.drop('index',inplace=True,axis=1)

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         james cameron            cch pounder  joel david moore
# 1        gore verbinski            johnny depp     orlando bloom
# 2            sam mendes        christoph waltz      rory kinnear
# 3     christopher nolan              tom hardy    christian bale
# 4           doug walker            doug walker        rob walker
# ...                 ...                    ...               ...
# 6133        pete docter             jamie foxx          tina fey
# 6134   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6135        regina king      kingsley ben-adir         eli goree
# 6136    emerald fennell         carey mulligan        bo burnham
# 6137   kornél mundruczó          vanessa kirby      shia labeouf
#
#               actor_3_name                                 genres  \
# 0                wes studi        action adventure fantasy sci-fi
# ...

# %%
df.tail(60)
# Out:
#                                           director_name  \
# 6078                                      justin simien
# 6079                                        nicol paone
# 6080                                   zoe lister-jones
# 6081                                     john whitesell
# 6082                                        jacob chase
# 6083                                        max winkler
# 6084                                     thomas bezucha
# 6085                                  andrea di stefano
# 6086                                      bryan bertino
# 6087                                         ron howard
# 6088                                      david fincher
# 6089                                 christopher landon
# 6090                                   david e. talbert
# 6091                             miles joris-peyrafitte
# 6092  eshom nelms, ian nelms (directors/screenplay);...
# 6093                                      edoardo ponti
# ...

# %%
df.to_csv('movies_final_data')

# %%
d=pd.read_csv('movies_final_data')
d
# Out:
#       Unnamed: 0      director_name           actor_1_name      actor_2_name  \
# 0              0      james cameron            cch pounder  joel david moore
# 1              1     gore verbinski            johnny depp     orlando bloom
# 2              2         sam mendes        christoph waltz      rory kinnear
# 3              3  christopher nolan              tom hardy    christian bale
# 4              4        doug walker            doug walker        rob walker
# ...          ...                ...                    ...               ...
# 6133        6133        pete docter             jamie foxx          tina fey
# 6134        6134   robert rodriguez  priyanka chopra jonas      pedro pascal
# 6135        6135        regina king      kingsley ben-adir         eli goree
# 6136        6136    emerald fennell         carey mulligan        bo burnham
# 6137        6137   kornél mundruczó          vanessa kirby      shia labeouf
#
# ...
