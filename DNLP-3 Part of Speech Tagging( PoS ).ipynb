# %%
import nltk
nltk.download('punkt')

sentence='My name is Muhammad Talha'

tokens=nltk.word_tokenize(sentence)

tokens
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Muhammad Talha
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['My', 'name', 'is', 'Muhammad', 'Talha']

# %%
nltk.download('averaged_perceptron_tagger')

nltk.pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Muhammad Talha
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [('My', 'PRP$'),
#  ('name', 'NN'),
#  ('is', 'VBZ'),
#  ('Muhammad', 'NNP'),
#  ('Talha', 'NNP')]

# %%
nltk.download('tagsets')
nltk.help.upenn_tagset()
# Out:
# [nltk_data] Downloading package tagsets to C:\Users\Muhammad Talha
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping help\tagsets.zip.
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
# ...

# %%
nltk.help.upenn_tagset('VBZ')
# Out:
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
# Chunking 
# import nltk 

sentences="""Lorem ipsum dolor sit amet, consectetur adipiscing elit. 
Suspendisse ornare lorem ac arcu semper, et iaculis nisl dapibus. 
Sed ullamcorper dui in lacus finibus rhoncus. Etiam eu congue elit, a aliquam purus.
Pellentesque volutpat dapibus massa viverra vehicula. Vestibulum eget consectetur 
odio, et ultrices erat. Integer sollicitudin neque et risus cursus, accumsan consequat sem commodo. Maecenas id urna 
eu lacus hendrerit vestibulum vitae ultrices dolor. Mauris dignissim, mauris et congue cursus, 
nisl enim ornare eros, in placerat nisl ligula eget sem. Morbi aliquam facilisis libero, eu egestas diam auctor et. 
Vivamus fringilla quam tellus, sit amet elementum leo ultrices vel. Maecenas sit amet fermentum nunc, nec posuere lorem. 
Phasellus consequat tellus a mi elementum molestie. Vestibulum malesuada massa sit amet felis venenatis, pulvinar dictum 
elit placerat.Mauris cursus metus ac libero consequat, vel eleifend tortor vulputate."""
tagged = nltk.pos_tag(nltk.word_tokenize(sentences))
tagged
# Out:
# [('Lorem', 'NNP'),
#  ('ipsum', 'NN'),
#  ('dolor', 'NN'),
#  ('sit', 'NN'),
#  ('amet', 'NN'),
#  (',', ','),
#  ('consectetur', 'NN'),
#  ('adipiscing', 'VBG'),
#  ('elit', 'NN'),
#  ('.', '.'),
#  ('Suspendisse', 'NNP'),
#  ('ornare', 'NN'),
#  ('lorem', 'NN'),
#  ('ac', 'NN'),
#  ('arcu', 'NN'),
#  ('semper', 'NN'),
#  (',', ','),
#  ('et', 'CC'),
#  ('iaculis', 'JJ'),
#  ('nisl', 'JJ'),
#  ('dapibus', 'NN'),
#  ('.', '.'),
#  ('Sed', 'NNP'),
#  ('ullamcorper', 'JJ'),
#  ('dui', 'NN'),
#  ('in', 'IN'),
#  ('lacus', 'NN'),
#  ('finibus', 'NN'),
#  ('rhoncus', 'NN'),
#  ('.', '.'),
#  ('Etiam', 'NNP'),
#  ('eu', 'JJ'),
#  ('congue', 'NN'),
#  ('elit', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('aliquam', 'JJ'),
#  ('purus', 'NN'),
#  ('.', '.'),
#  ('Pellentesque', 'NNP'),
#  ('volutpat', 'JJ'),
#  ('dapibus', 'NN'),
#  ('massa', 'NN'),
#  ('viverra', 'NN'),
#  ('vehicula', 'NN'),
#  ('.', '.'),
#  ('Vestibulum', 'NNP'),
#  ('eget', 'NN'),
#  ('consectetur', 'NN'),
# ...

# %%
grammar=('''
    NP: {<DT>?<JJ>*<NN>}  #NP
   ''')

chunkParser=nltk.RegexpParser(grammar)
tree= chunkParser.parse(tagged)
tree.draw()
